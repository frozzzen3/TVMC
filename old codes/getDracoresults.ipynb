# %%
import subprocess
import os
import time
import numpy as np
import open3d as o3d
import re

# %%
dataset = 'Dancer'
GoF = 5

# %%
input_dir = os.path.join(r'G:\VS2022Projects\tvm-editing-master\TVMEditor.Test\bin\Release\net5.0\Data', os.path.join(dataset, 'meshes'))

output_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\encode_Draco', dataset)
print(input_dir)
print(output_root_dir)
# Out:
# G:\VS2022Projects\tvm-editing-master\TVMEditor.Test\bin\Release\net5.0\Data\Dancer\meshes
# G:\PycharmProjects\Mesh_Editing\Results\encode_Draco\Dancer

# %% [markdown]
# ## Encode

# %%
input_dir = os.path.join(r'G:\VS2022Projects\tvm-editing-master\TVMEditor.Test\bin\Release\net5.0\Data', os.path.join(dataset, 'meshes'))
output_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\encode_Draco', dataset)

obj_files = [f for f in os.listdir(input_dir) if f.endswith('.obj')]

qps = range(0,15) # qp from 0 to 14, small qp (qp <=3 or 4) is meaningless

for qp in qps:
    output_dir = os.path.join(output_root_dir, f'{dataset}_qp_{qp}')
    os.makedirs(output_dir, exist_ok=True)

    output_file = os.path.join(output_dir, f'encoding_times_qp_{qp}.txt')
    with open(output_file, 'w') as f:
        total_encoding_time = 0
        for obj_file in obj_files:

            input_path = os.path.join(input_dir, obj_file)
            output_path = os.path.join(output_dir, obj_file.replace('.obj', f'_qp_{qp}.drc'))

            start_time = time.time()

            result = subprocess.run([
                            r'G:\Github\draco\build\Debug\draco_encoder',
                            '-i', input_path,
                            '-o', output_path,
                            '-qp', str(qp)
                            ], capture_output=True, text=True)
            print(result.stdout)
            end_time = time.time()

            encoding_time = end_time - start_time
            total_encoding_time += encoding_time
            print(f"Encoded {obj_file} in {encoding_time:.4f} seconds")
            f.write(f"Encoded {obj_file} in {encoding_time:.4f} seconds\n")

        total_files = len(obj_files)
        average_encoding_time = total_encoding_time / total_files

        f.write(f"\nTotal encoding time for qp {qp}: {total_encoding_time:.4f} seconds\n")
        f.write(f"Average encoding time for qp {qp}: {average_encoding_time:.4f} seconds\n\n")
# Out:
# Encoded dancer_fr0005.obj in 0.3218 seconds
# Encoded dancer_fr0006.obj in 0.3010 seconds
# Encoded dancer_fr0007.obj in 0.2980 seconds
# Encoded dancer_fr0008.obj in 0.2940 seconds
# Encoded dancer_fr0009.obj in 0.2920 seconds
# Encoded dancer_fr0010.obj in 0.2900 seconds
# Encoded dancer_fr0011.obj in 0.2920 seconds
# Encoded dancer_fr0012.obj in 0.2924 seconds
# Encoded dancer_fr0013.obj in 0.2900 seconds
# Encoded dancer_fr0014.obj in 0.3240 seconds
# Encoded dancer_fr0015.obj in 0.2910 seconds
# Encoded dancer_fr0016.obj in 0.2900 seconds
# Encoded dancer_fr0017.obj in 0.2920 seconds
# Encoded dancer_fr0018.obj in 0.3010 seconds
# Encoded dancer_fr0019.obj in 0.2910 seconds
# Encoded dancer_fr0005.obj in 0.2933 seconds
# Encoded dancer_fr0006.obj in 0.2910 seconds
# Encoded dancer_fr0007.obj in 0.2890 seconds
# Encoded dancer_fr0008.obj in 0.2910 seconds
# Encoded dancer_fr0009.obj in 0.2944 seconds
# Encoded dancer_fr0010.obj in 0.3050 seconds
# Encoded dancer_fr0011.obj in 0.2910 seconds
# Encoded dancer_fr0012.obj in 0.2919 seconds
# Encoded dancer_fr0013.obj in 0.2900 seconds
# Encoded dancer_fr0014.obj in 0.3230 seconds
# Encoded dancer_fr0015.obj in 0.2940 seconds
# Encoded dancer_fr0016.obj in 0.2870 seconds
# Encoded dancer_fr0017.obj in 0.2900 seconds
# Encoded dancer_fr0018.obj in 0.2910 seconds
# Encoded dancer_fr0019.obj in 0.2899 seconds
# Encoded dancer_fr0005.obj in 0.2930 seconds
# Encoded dancer_fr0006.obj in 0.2890 seconds
# Encoded dancer_fr0007.obj in 0.3140 seconds
# Encoded dancer_fr0008.obj in 0.3010 seconds
# Encoded dancer_fr0009.obj in 0.2950 seconds
# Encoded dancer_fr0010.obj in 0.2945 seconds
# Encoded dancer_fr0011.obj in 0.2950 seconds
# Encoded dancer_fr0012.obj in 0.2910 seconds
# Encoded dancer_fr0013.obj in 0.2910 seconds
# Encoded dancer_fr0014.obj in 0.3190 seconds
# Encoded dancer_fr0015.obj in 0.2960 seconds
# Encoded dancer_fr0016.obj in 0.2930 seconds
# Encoded dancer_fr0017.obj in 0.2890 seconds
# Encoded dancer_fr0018.obj in 0.2880 seconds
# Encoded dancer_fr0019.obj in 0.2900 seconds
# Encoded dancer_fr0005.obj in 0.2910 seconds
# Encoded dancer_fr0006.obj in 0.2920 seconds
# Encoded dancer_fr0007.obj in 0.2910 seconds
# Encoded dancer_fr0008.obj in 0.2900 seconds
# Encoded dancer_fr0009.obj in 0.2990 seconds
# Encoded dancer_fr0010.obj in 0.2880 seconds
# Encoded dancer_fr0011.obj in 0.2950 seconds
# Encoded dancer_fr0012.obj in 0.2910 seconds
# Encoded dancer_fr0013.obj in 0.2892 seconds
# Encoded dancer_fr0014.obj in 0.3090 seconds
# Encoded dancer_fr0015.obj in 0.2920 seconds
# Encoded dancer_fr0016.obj in 0.2870 seconds
# Encoded dancer_fr0017.obj in 0.2880 seconds
# Encoded dancer_fr0018.obj in 0.2890 seconds
# Encoded dancer_fr0019.obj in 0.2850 seconds
# Encoded dancer_fr0005.obj in 0.2890 seconds
# Encoded dancer_fr0006.obj in 0.2910 seconds
# Encoded dancer_fr0007.obj in 0.2880 seconds
# Encoded dancer_fr0008.obj in 0.2960 seconds
# Encoded dancer_fr0009.obj in 0.2880 seconds
# Encoded dancer_fr0010.obj in 0.2880 seconds
# Encoded dancer_fr0011.obj in 0.2880 seconds
# Encoded dancer_fr0012.obj in 0.2880 seconds
# Encoded dancer_fr0013.obj in 0.3000 seconds
# Encoded dancer_fr0014.obj in 0.3108 seconds
# Encoded dancer_fr0015.obj in 0.2962 seconds
# Encoded dancer_fr0016.obj in 0.2920 seconds
# Encoded dancer_fr0017.obj in 0.2890 seconds
# Encoded dancer_fr0018.obj in 0.2950 seconds
# Encoded dancer_fr0019.obj in 0.2920 seconds
# Encoded dancer_fr0005.obj in 0.2920 seconds
# Encoded dancer_fr0006.obj in 0.2920 seconds
# Encoded dancer_fr0007.obj in 0.2920 seconds
# Encoded dancer_fr0008.obj in 0.2910 seconds
# Encoded dancer_fr0009.obj in 0.2910 seconds
# Encoded dancer_fr0010.obj in 0.2940 seconds
# Encoded dancer_fr0011.obj in 0.2960 seconds
# Encoded dancer_fr0012.obj in 0.2940 seconds
# Encoded dancer_fr0013.obj in 0.3310 seconds
# Encoded dancer_fr0014.obj in 0.3550 seconds
# Encoded dancer_fr0015.obj in 0.3020 seconds
# Encoded dancer_fr0016.obj in 0.3060 seconds
# Encoded dancer_fr0017.obj in 0.2950 seconds
# Encoded dancer_fr0018.obj in 0.2890 seconds
# Encoded dancer_fr0019.obj in 0.2940 seconds
# Encoded dancer_fr0005.obj in 0.2931 seconds
# Encoded dancer_fr0006.obj in 0.3100 seconds
# Encoded dancer_fr0007.obj in 0.2970 seconds
# Encoded dancer_fr0008.obj in 0.2970 seconds
# Encoded dancer_fr0009.obj in 0.3020 seconds
# Encoded dancer_fr0010.obj in 0.2970 seconds
# Encoded dancer_fr0011.obj in 0.2940 seconds
# Encoded dancer_fr0012.obj in 0.2970 seconds
# Encoded dancer_fr0013.obj in 0.2930 seconds
# Encoded dancer_fr0014.obj in 0.3160 seconds
# Encoded dancer_fr0015.obj in 0.2990 seconds
# Encoded dancer_fr0016.obj in 0.2930 seconds
# Encoded dancer_fr0017.obj in 0.2890 seconds
# Encoded dancer_fr0018.obj in 0.3030 seconds
# Encoded dancer_fr0019.obj in 0.3010 seconds
# Encoded dancer_fr0005.obj in 0.2950 seconds
# Encoded dancer_fr0006.obj in 0.2940 seconds
# Encoded dancer_fr0007.obj in 0.2972 seconds
# Encoded dancer_fr0008.obj in 0.3040 seconds
# Encoded dancer_fr0009.obj in 0.2990 seconds
# Encoded dancer_fr0010.obj in 0.2930 seconds
# Encoded dancer_fr0011.obj in 0.2930 seconds
# Encoded dancer_fr0012.obj in 0.2900 seconds
# Encoded dancer_fr0013.obj in 0.2900 seconds
# Encoded dancer_fr0014.obj in 0.3120 seconds
# Encoded dancer_fr0015.obj in 0.3020 seconds
# Encoded dancer_fr0016.obj in 0.2900 seconds
# Encoded dancer_fr0017.obj in 0.2890 seconds
# Encoded dancer_fr0018.obj in 0.2870 seconds
# Encoded dancer_fr0019.obj in 0.2940 seconds
# Encoded dancer_fr0005.obj in 0.2910 seconds
# Encoded dancer_fr0006.obj in 0.2960 seconds
# Encoded dancer_fr0007.obj in 0.3010 seconds
# Encoded dancer_fr0008.obj in 0.2970 seconds
# Encoded dancer_fr0009.obj in 0.2970 seconds
# Encoded dancer_fr0010.obj in 0.2860 seconds
# Encoded dancer_fr0011.obj in 0.2870 seconds
# Encoded dancer_fr0012.obj in 0.2910 seconds
# Encoded dancer_fr0013.obj in 0.2870 seconds
# Encoded dancer_fr0014.obj in 0.3190 seconds
# Encoded dancer_fr0015.obj in 0.2900 seconds
# Encoded dancer_fr0016.obj in 0.2930 seconds
# Encoded dancer_fr0017.obj in 0.2880 seconds
# Encoded dancer_fr0018.obj in 0.2890 seconds
# Encoded dancer_fr0019.obj in 0.2930 seconds
# Encoded dancer_fr0005.obj in 0.2880 seconds
# Encoded dancer_fr0006.obj in 0.2890 seconds
# Encoded dancer_fr0007.obj in 0.2880 seconds
# Encoded dancer_fr0008.obj in 0.2970 seconds
# Encoded dancer_fr0009.obj in 0.2924 seconds
# Encoded dancer_fr0010.obj in 0.2930 seconds
# Encoded dancer_fr0011.obj in 0.2880 seconds
# Encoded dancer_fr0012.obj in 0.2940 seconds
# Encoded dancer_fr0013.obj in 0.2890 seconds
# Encoded dancer_fr0014.obj in 0.3050 seconds
# Encoded dancer_fr0015.obj in 0.2890 seconds
# Encoded dancer_fr0016.obj in 0.2900 seconds
# Encoded dancer_fr0017.obj in 0.2900 seconds
# Encoded dancer_fr0018.obj in 0.2900 seconds
# Encoded dancer_fr0019.obj in 0.2890 seconds
# Encoded dancer_fr0005.obj in 0.2900 seconds
# Encoded dancer_fr0006.obj in 0.2930 seconds
# Encoded dancer_fr0007.obj in 0.2900 seconds
# Encoded dancer_fr0008.obj in 0.2880 seconds
# Encoded dancer_fr0009.obj in 0.2890 seconds
# Encoded dancer_fr0010.obj in 0.2920 seconds
# Encoded dancer_fr0011.obj in 0.2920 seconds
# Encoded dancer_fr0012.obj in 0.2870 seconds
# Encoded dancer_fr0013.obj in 0.2920 seconds
# Encoded dancer_fr0014.obj in 0.3110 seconds
# Encoded dancer_fr0015.obj in 0.2910 seconds
# Encoded dancer_fr0016.obj in 0.2920 seconds
# Encoded dancer_fr0017.obj in 0.2890 seconds
# Encoded dancer_fr0018.obj in 0.2880 seconds
# Encoded dancer_fr0019.obj in 0.2940 seconds
# Encoded dancer_fr0005.obj in 0.2916 seconds
# Encoded dancer_fr0006.obj in 0.2890 seconds
# Encoded dancer_fr0007.obj in 0.2940 seconds
# Encoded dancer_fr0008.obj in 0.2990 seconds
# Encoded dancer_fr0009.obj in 0.3020 seconds
# Encoded dancer_fr0010.obj in 0.2960 seconds
# Encoded dancer_fr0011.obj in 0.2880 seconds
# Encoded dancer_fr0012.obj in 0.2930 seconds
# Encoded dancer_fr0013.obj in 0.2880 seconds
# Encoded dancer_fr0014.obj in 0.3070 seconds
# Encoded dancer_fr0015.obj in 0.2930 seconds
# Encoded dancer_fr0016.obj in 0.2904 seconds
# Encoded dancer_fr0017.obj in 0.2960 seconds
# Encoded dancer_fr0018.obj in 0.2920 seconds
# Encoded dancer_fr0019.obj in 0.2901 seconds
# Encoded dancer_fr0005.obj in 0.2910 seconds
# Encoded dancer_fr0006.obj in 0.2890 seconds
# Encoded dancer_fr0007.obj in 0.2920 seconds
# Encoded dancer_fr0008.obj in 0.2900 seconds
# Encoded dancer_fr0009.obj in 0.2980 seconds
# Encoded dancer_fr0010.obj in 0.2900 seconds
# Encoded dancer_fr0011.obj in 0.2897 seconds
# Encoded dancer_fr0012.obj in 0.2905 seconds
# Encoded dancer_fr0013.obj in 0.2875 seconds
# Encoded dancer_fr0014.obj in 0.3065 seconds
# Encoded dancer_fr0015.obj in 0.2920 seconds
# Encoded dancer_fr0016.obj in 0.2914 seconds
# Encoded dancer_fr0017.obj in 0.2880 seconds
# Encoded dancer_fr0018.obj in 0.2940 seconds
# Encoded dancer_fr0019.obj in 0.2930 seconds
# Encoded dancer_fr0005.obj in 0.2900 seconds
# Encoded dancer_fr0006.obj in 0.2923 seconds
# Encoded dancer_fr0007.obj in 0.2900 seconds
# Encoded dancer_fr0008.obj in 0.2920 seconds
# Encoded dancer_fr0009.obj in 0.2890 seconds
# Encoded dancer_fr0010.obj in 0.2880 seconds
# Encoded dancer_fr0011.obj in 0.2860 seconds
# Encoded dancer_fr0012.obj in 0.2890 seconds
# Encoded dancer_fr0013.obj in 0.2900 seconds
# Encoded dancer_fr0014.obj in 0.3070 seconds
# Encoded dancer_fr0015.obj in 0.2930 seconds
# Encoded dancer_fr0016.obj in 0.2980 seconds
# Encoded dancer_fr0017.obj in 0.2890 seconds
# Encoded dancer_fr0018.obj in 0.2880 seconds
# Encoded dancer_fr0019.obj in 0.2900 seconds
# Encoded dancer_fr0005.obj in 0.2889 seconds
# Encoded dancer_fr0006.obj in 0.2960 seconds
# Encoded dancer_fr0007.obj in 0.2930 seconds
# Encoded dancer_fr0008.obj in 0.2940 seconds
# Encoded dancer_fr0009.obj in 0.2920 seconds
# Encoded dancer_fr0010.obj in 0.2917 seconds
# Encoded dancer_fr0011.obj in 0.2940 seconds
# Encoded dancer_fr0012.obj in 0.2940 seconds
# Encoded dancer_fr0013.obj in 0.2930 seconds
# Encoded dancer_fr0014.obj in 0.3150 seconds
# Encoded dancer_fr0015.obj in 0.2930 seconds
# Encoded dancer_fr0016.obj in 0.2940 seconds
# Encoded dancer_fr0017.obj in 0.2930 seconds
# Encoded dancer_fr0018.obj in 0.2920 seconds
# Encoded dancer_fr0019.obj in 0.2910 seconds

# %% [markdown]
# ## Decode

# %%
input_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\encode_Draco', dataset)
output_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\decode_Draco', dataset)
print(input_root_dir)
print(output_root_dir)
# Out:
# G:\PycharmProjects\Mesh_Editing\Results\encode_Draco\Dancer
# G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer

# %%
input_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\encode_Draco', dataset)
output_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\decode_Draco', dataset)
os.makedirs(output_root_dir, exist_ok=True)


qps = range(0,15)

for qp in qps:
    output_dir = os.path.join(output_root_dir, f'{dataset}_qp_{qp}')
    os.makedirs(output_dir, exist_ok=True)
    input_dir = os.path.join(input_root_dir, f'{dataset}_qp_{qp}')
    drc_files = [f for f in os.listdir(input_dir) if f.endswith('.drc')]
    output_file = os.path.join(output_dir, f'decoding_times_qp_{qp}.txt')
    with open(output_file, 'w') as f:
        total_decoding_time = 0
        for drc_file in drc_files:
            input_path = os.path.join(input_dir, drc_file)
            output_path = os.path.join(output_dir, drc_file.replace(f'_qp_{qp}.drc', f'_qp_{qp}_decoded.obj'))
            start_time = time.time()

            # Use subprocess to execute the draco_decoder command
            result = subprocess.run([
                                    r'G:\Github\draco\build\Debug\draco_decoder', 
                                    '-i', input_path,
                                    '-o', output_path
                                    ], capture_output=True, text=True)
            print(result.stdout)
            end_time = time.time()

            decoding_time = end_time - start_time
            total_decoding_time += decoding_time
            print(f"Decoded {drc_file} in {decoding_time:.4f} seconds")
            f.write(f"Decoded {drc_file} in {decoding_time:.4f} seconds\n")
        total_files = len(drc_files)
        average_decoding_time = total_decoding_time / total_files

        f.write(f"\nTotal decoding time for qp {qp}: {total_decoding_time:.4f} seconds\n")
        f.write(f"Average decoding time for qp {qp}: {average_decoding_time:.4f} seconds\n\n")
# Out:
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0005_qp_0_decoded.obj (44 ms to decode)
#
# Decoded dancer_fr0005_qp_0.drc in 0.2085 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0006_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0006_qp_0.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0007_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0007_qp_0.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0008_qp_0_decoded.obj (44 ms to decode)
#
# Decoded dancer_fr0008_qp_0.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0009_qp_0_decoded.obj (43 ms to decode)
#
# Decoded dancer_fr0009_qp_0.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0010_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0010_qp_0.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0011_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0011_qp_0.drc in 0.2060 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0012_qp_0_decoded.obj (41 ms to decode)
#
# Decoded dancer_fr0012_qp_0.drc in 0.2040 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0013_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0013_qp_0.drc in 0.2060 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0014_qp_0_decoded.obj (41 ms to decode)
#
# Decoded dancer_fr0014_qp_0.drc in 0.2045 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0015_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0015_qp_0.drc in 0.2074 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0016_qp_0_decoded.obj (41 ms to decode)
#
# Decoded dancer_fr0016_qp_0.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0017_qp_0_decoded.obj (43 ms to decode)
#
# Decoded dancer_fr0017_qp_0.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0018_qp_0_decoded.obj (41 ms to decode)
#
# Decoded dancer_fr0018_qp_0.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_0\dancer_fr0019_qp_0_decoded.obj (42 ms to decode)
#
# Decoded dancer_fr0019_qp_0.drc in 0.2129 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0005_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_1.drc in 0.2098 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0006_qp_1_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0006_qp_1.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0007_qp_1_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0007_qp_1.drc in 0.2130 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0008_qp_1_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0008_qp_1.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0009_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0009_qp_1.drc in 0.2099 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0010_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_1.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0011_qp_1_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0011_qp_1.drc in 0.2134 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0012_qp_1_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0012_qp_1.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0013_qp_1_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_1.drc in 0.2088 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0014_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_1.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0015_qp_1_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0015_qp_1.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0016_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_1.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0017_qp_1_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0017_qp_1.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0018_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0018_qp_1.drc in 0.2093 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_1\dancer_fr0019_qp_1_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_1.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0005_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0005_qp_2.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0006_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0006_qp_2.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0007_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0007_qp_2.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0008_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0008_qp_2.drc in 0.2082 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0009_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0009_qp_2.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0010_qp_2_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_2.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0011_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0011_qp_2.drc in 0.2096 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0012_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0012_qp_2.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0013_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_2.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0014_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0014_qp_2.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0015_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0015_qp_2.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0016_qp_2_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_2.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0017_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0017_qp_2.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0018_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_2.drc in 0.2108 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_2\dancer_fr0019_qp_2_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0019_qp_2.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0005_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0005_qp_3.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0006_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0006_qp_3.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0007_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0007_qp_3.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0008_qp_3_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0008_qp_3.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0009_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0009_qp_3.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0010_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0010_qp_3.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0011_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0011_qp_3.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0012_qp_3_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0012_qp_3.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0013_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_3.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0014_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0014_qp_3.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0015_qp_3_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0015_qp_3.drc in 0.2123 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0016_qp_3_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_3.drc in 0.2109 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0017_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0017_qp_3.drc in 0.2087 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0018_qp_3_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0018_qp_3.drc in 0.2105 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_3\dancer_fr0019_qp_3_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0019_qp_3.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0005_qp_4_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_4.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0006_qp_4_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_4.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0007_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0007_qp_4.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0008_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0008_qp_4.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0009_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0009_qp_4.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0010_qp_4_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0010_qp_4.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0011_qp_4_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0011_qp_4.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0012_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0012_qp_4.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0013_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_4.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0014_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0014_qp_4.drc in 0.2109 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0015_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0015_qp_4.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0016_qp_4_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_4.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0017_qp_4_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_4.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0018_qp_4_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_4.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_4\dancer_fr0019_qp_4_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_4.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0005_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_5.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0006_qp_5_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0006_qp_5.drc in 0.2184 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0007_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0007_qp_5.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0008_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0008_qp_5.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0009_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0009_qp_5.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0010_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_5.drc in 0.2106 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0011_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0011_qp_5.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0012_qp_5_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0012_qp_5.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0013_qp_5_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_5.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0014_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_5.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0015_qp_5_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0015_qp_5.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0016_qp_5_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0016_qp_5.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0017_qp_5_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0017_qp_5.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0018_qp_5_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_5.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_5\dancer_fr0019_qp_5_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_5.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0005_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0006_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_6.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0007_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0007_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0008_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0008_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0009_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0009_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0010_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0010_qp_6.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0011_qp_6_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0011_qp_6.drc in 0.2097 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0012_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0012_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0013_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0014_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0014_qp_6.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0015_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0015_qp_6.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0016_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_6.drc in 0.2095 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0017_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_6.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0018_qp_6_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_6.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_6\dancer_fr0019_qp_6_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_6.drc in 0.2130 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0005_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_7.drc in 0.2109 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0006_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_7.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0007_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0007_qp_7.drc in 0.2099 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0008_qp_7_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0008_qp_7.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0009_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0009_qp_7.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0010_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_7.drc in 0.2097 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0011_qp_7_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0011_qp_7.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0012_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0012_qp_7.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0013_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0013_qp_7.drc in 0.2160 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0014_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_7.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0015_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0015_qp_7.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0016_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_7.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0017_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_7.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0018_qp_7_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_7.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_7\dancer_fr0019_qp_7_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_7.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0005_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_8.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0006_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_8.drc in 0.2125 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0007_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0007_qp_8.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0008_qp_8_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0008_qp_8.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0009_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0009_qp_8.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0010_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_8.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0011_qp_8_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0011_qp_8.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0012_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0012_qp_8.drc in 0.2217 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0013_qp_8_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_8.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0014_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_8.drc in 0.2111 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0015_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0015_qp_8.drc in 0.2118 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0016_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_8.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0017_qp_8_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_8.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0018_qp_8_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_8.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_8\dancer_fr0019_qp_8_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0019_qp_8.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0005_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_9.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0006_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_9.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0007_qp_9_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0007_qp_9.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0008_qp_9_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0008_qp_9.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0009_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0009_qp_9.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0010_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_9.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0011_qp_9_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0011_qp_9.drc in 0.2170 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0012_qp_9_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0012_qp_9.drc in 0.2070 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0013_qp_9_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_9.drc in 0.2101 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0014_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_9.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0015_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0015_qp_9.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0016_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_9.drc in 0.2109 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0017_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_9.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0018_qp_9_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_9.drc in 0.2104 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9\dancer_fr0019_qp_9_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_9.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0005_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_10.drc in 0.2130 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0006_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_10.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0007_qp_10_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0007_qp_10.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0008_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0008_qp_10.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0009_qp_10_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0009_qp_10.drc in 0.2170 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0010_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_10.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0011_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0011_qp_10.drc in 0.2111 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0012_qp_10_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0012_qp_10.drc in 0.2200 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0013_qp_10_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0013_qp_10.drc in 0.2130 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0014_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_10.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0015_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0015_qp_10.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0016_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_10.drc in 0.2103 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0017_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_10.drc in 0.2160 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0018_qp_10_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0018_qp_10.drc in 0.2090 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_10\dancer_fr0019_qp_10_decoded.obj (52 ms to decode)
#
# Decoded dancer_fr0019_qp_10.drc in 0.2173 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0005_qp_11_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0005_qp_11.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0006_qp_11_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0006_qp_11.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0007_qp_11_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0007_qp_11.drc in 0.2160 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0008_qp_11_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0008_qp_11.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0009_qp_11_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0009_qp_11.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0010_qp_11_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0010_qp_11.drc in 0.2190 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0011_qp_11_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0011_qp_11.drc in 0.2239 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0012_qp_11_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0012_qp_11.drc in 0.2106 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0013_qp_11_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0013_qp_11.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0014_qp_11_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0014_qp_11.drc in 0.2230 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0015_qp_11_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0015_qp_11.drc in 0.2180 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0016_qp_11_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0016_qp_11.drc in 0.2210 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0017_qp_11_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_11.drc in 0.2080 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0018_qp_11_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0018_qp_11.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_11\dancer_fr0019_qp_11_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_11.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0005_qp_12_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_12.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0006_qp_12_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0006_qp_12.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0007_qp_12_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0007_qp_12.drc in 0.2123 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0008_qp_12_decoded.obj (45 ms to decode)
#
# Decoded dancer_fr0008_qp_12.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0009_qp_12_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0009_qp_12.drc in 0.2200 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0010_qp_12_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0010_qp_12.drc in 0.2206 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0011_qp_12_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0011_qp_12.drc in 0.2215 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0012_qp_12_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0012_qp_12.drc in 0.2240 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0013_qp_12_decoded.obj (49 ms to decode)
#
# Decoded dancer_fr0013_qp_12.drc in 0.2170 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0014_qp_12_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0014_qp_12.drc in 0.2150 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0015_qp_12_decoded.obj (51 ms to decode)
#
# Decoded dancer_fr0015_qp_12.drc in 0.2200 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0016_qp_12_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0016_qp_12.drc in 0.2230 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0017_qp_12_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_12.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0018_qp_12_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0018_qp_12.drc in 0.2117 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_12\dancer_fr0019_qp_12_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_12.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0005_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0005_qp_13.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0006_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0006_qp_13.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0007_qp_13_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0007_qp_13.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0008_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0008_qp_13.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0009_qp_13_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0009_qp_13.drc in 0.2140 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0010_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0010_qp_13.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0011_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0011_qp_13.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0012_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0012_qp_13.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0013_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0013_qp_13.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0014_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0014_qp_13.drc in 0.2100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0015_qp_13_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0015_qp_13.drc in 0.2130 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0016_qp_13_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0016_qp_13.drc in 0.2190 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0017_qp_13_decoded.obj (53 ms to decode)
#
# Decoded dancer_fr0017_qp_13.drc in 0.2270 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0018_qp_13_decoded.obj (57 ms to decode)
#
# Decoded dancer_fr0018_qp_13.drc in 0.2400 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_13\dancer_fr0019_qp_13_decoded.obj (58 ms to decode)
#
# Decoded dancer_fr0019_qp_13.drc in 0.2280 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0005_qp_14_decoded.obj (48 ms to decode)
#
# Decoded dancer_fr0005_qp_14.drc in 0.2200 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0006_qp_14_decoded.obj (54 ms to decode)
#
# Decoded dancer_fr0006_qp_14.drc in 0.2460 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0007_qp_14_decoded.obj (89 ms to decode)
#
# Decoded dancer_fr0007_qp_14.drc in 0.3100 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0008_qp_14_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0008_qp_14.drc in 0.2300 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0009_qp_14_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0009_qp_14.drc in 0.2600 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0010_qp_14_decoded.obj (67 ms to decode)
#
# Decoded dancer_fr0010_qp_14.drc in 0.2640 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0011_qp_14_decoded.obj (68 ms to decode)
#
# Decoded dancer_fr0011_qp_14.drc in 0.2420 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0012_qp_14_decoded.obj (60 ms to decode)
#
# Decoded dancer_fr0012_qp_14.drc in 0.2440 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0013_qp_14_decoded.obj (51 ms to decode)
#
# Decoded dancer_fr0013_qp_14.drc in 0.2360 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0014_qp_14_decoded.obj (62 ms to decode)
#
# Decoded dancer_fr0014_qp_14.drc in 0.2760 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0015_qp_14_decoded.obj (52 ms to decode)
#
# Decoded dancer_fr0015_qp_14.drc in 0.2190 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0016_qp_14_decoded.obj (50 ms to decode)
#
# Decoded dancer_fr0016_qp_14.drc in 0.2180 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0017_qp_14_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0017_qp_14.drc in 0.2110 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0018_qp_14_decoded.obj (47 ms to decode)
#
# Decoded dancer_fr0018_qp_14.drc in 0.2120 seconds
# Decoded geometry saved to G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_14\dancer_fr0019_qp_14_decoded.obj (46 ms to decode)
#
# Decoded dancer_fr0019_qp_14.drc in 0.2120 seconds

# %% [markdown]
# ## Calculate Bitrate

# %%
frame_rate = 30 # the requirement for real-time (30 fps in both encoder/decoder) performance
number_frames = 5

# %%
import os

def calculate_bitrate(file_size, duration):
    return file_size * 8 / duration

input_root_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\encode_Draco', dataset)

qps = range(6,15) # qp < 6 is useless
for qp in qps:
    total_size = 0
    input_dir = os.path.join(input_root_dir, f'{dataset}_qp_{qp}')
    drc_files = [f for f in os.listdir(input_dir) if f.endswith('.drc')]
    
    for i in range(number_frames):
        file_path = os.path.join(input_dir, drc_files[i])
        file_size = os.path.getsize(file_path)
        total_size += file_size

    total_duration = number_frames / frame_rate
    overall_bitrate = calculate_bitrate(total_size, total_duration)
    
    print(f"Total Size of {number_frames} DRC Files: {total_size} bytes")
    print(f"Overall Bitrate: {overall_bitrate} bits per second")

    bitrate_kbps = overall_bitrate / 1000
    bitrate_mbps = overall_bitrate / 1000000
    

    print(f"Overall Bitrate: {bitrate_kbps:.2f} Kbps")
    print(f"Overall Bitrate: {bitrate_mbps:.2f} Mbps")
    
    output_file = os.path.join(input_dir, f'{dataset}_qp_{qp}_GoF_{number_frames}_bitrate_info.txt')
    with open(output_file, 'w') as file:
        file.write(f"Total Size of {number_frames} DRC Files: {total_size} bytes\n")
        file.write(f"Overall Bitrate: {overall_bitrate} bits per second\n")
        file.write(f"Overall Bitrate: {bitrate_kbps:.2f} Kbps\n")
        file.write(f"Overall Bitrate: {bitrate_mbps:.2f} Mbps\n")
    
    print("Bitrate information has been saved to 'bitrate_info.txt'")
# Out:
# Total Size of 15 DRC Files: 206809 bytes
# Overall Bitrate: 3308944.0 bits per second
# Overall Bitrate: 3308.94 Kbps
# Overall Bitrate: 3.31 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 249429 bytes
# Overall Bitrate: 3990864.0 bits per second
# Overall Bitrate: 3990.86 Kbps
# Overall Bitrate: 3.99 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 304711 bytes
# Overall Bitrate: 4875376.0 bits per second
# Overall Bitrate: 4875.38 Kbps
# Overall Bitrate: 4.88 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 383390 bytes
# Overall Bitrate: 6134240.0 bits per second
# Overall Bitrate: 6134.24 Kbps
# Overall Bitrate: 6.13 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 482894 bytes
# Overall Bitrate: 7726304.0 bits per second
# Overall Bitrate: 7726.30 Kbps
# Overall Bitrate: 7.73 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 590058 bytes
# Overall Bitrate: 9440928.0 bits per second
# Overall Bitrate: 9440.93 Kbps
# Overall Bitrate: 9.44 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 701769 bytes
# Overall Bitrate: 11228304.0 bits per second
# Overall Bitrate: 11228.30 Kbps
# Overall Bitrate: 11.23 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 800844 bytes
# Overall Bitrate: 12813504.0 bits per second
# Overall Bitrate: 12813.50 Kbps
# Overall Bitrate: 12.81 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'
# Total Size of 15 DRC Files: 818471 bytes
# Overall Bitrate: 13095536.0 bits per second
# Overall Bitrate: 13095.54 Kbps
# Overall Bitrate: 13.10 Mbps
# Bitrate information has been saved to 'bitrate_info.txt'

# %% [markdown]
# ## Get error

# %%
def normalize_point_cloud(pcd, min_range=0, max_range=1):
    points = np.asarray(pcd.points)
    
    min_bound = points.min(axis=0)
    max_bound = points.max(axis=0)
    
    normalized_points = (points - min_bound) / (max_bound - min_bound)  
    normalized_points = normalized_points * (max_range - min_range) + min_range  
    
    pcd.points = o3d.utility.Vector3dVector(normalized_points)
    return pcd

def normalize_vertices(vertices, min_range=0, max_range=1):
    min_bound = np.min(vertices, axis=0)
    max_bound = np.max(vertices, axis=0)
    
    normalized_vertices = (vertices - min_bound) / (max_bound - min_bound)
    
    normalized_vertices = normalized_vertices * (max_range - min_range) + min_range
    
    return normalized_vertices

# %%
def compute_D1_psnr(original_mesh, decoded_mesh):
    
    original_vertices = np.array(original_mesh.vertices)
    #original_vertices = normalize_vertices(original_vertices)
    decoded_vertices = np.array(decoded_mesh.vertices)
    #decoded_vertices = normalize_vertices(decoded_vertices)
    
    pcd_original = o3d.geometry.PointCloud()
    pcd_original.points = o3d.utility.Vector3dVector(original_vertices)
    
    pcd_decoded = o3d.geometry.PointCloud()
    pcd_decoded.points = o3d.utility.Vector3dVector(decoded_vertices)
    pcd_tree = o3d.geometry.KDTreeFlann(pcd_decoded)
    

    
    MSE = 0
    for i in range(0, len(original_vertices)):
        [k, index, _] = pcd_tree.search_knn_vector_3d(original_vertices[i], 1)
        MSE += np.square(original_vertices[i] - decoded_vertices[index])
    MSE = np.mean(MSE)
    
    aabb = pcd_original.get_axis_aligned_bounding_box()
    min_bound = aabb.get_min_bound()

    max_bound = aabb.get_max_bound()

    signal_peak = np.linalg.norm(max_bound - min_bound)
    psnr = 20 * np.log10(signal_peak) - 10 * np.log10(MSE)
    
    return psnr

# %%
original_input_dir = os.path.join(r'G:\VS2022Projects\tvm-editing-master\TVMEditor.Test\bin\Release\net5.0\Data', os.path.join(dataset, 'meshes'))
decoded_input_dir = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results\decode_Draco', dataset)

files = os.listdir(original_input_dir)
original_obj_files = [file for file in files if file.endswith('.obj')]
def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(1)) if match else float('inf')

original_obj_files.sort(key=extract_number)
    
qps = range(6,15)
result_file_path = os.path.join(r'G:\PycharmProjects\Mesh_Editing\Results', f'{dataset}_D1_PSNR_results.txt')
with open(result_file_path, 'w') as result_file:
    for qp in qps:
        d1_psnr_values = []
        decoded_obj_path = os.path.join(decoded_input_dir, f'{dataset}_qp_{qp}')
        files = os.listdir(decoded_obj_path)
        decoded_obj_files = [file for file in files if file.endswith('.obj')]
        for i in range(len(original_obj_files)):
            original_mesh = o3d.io.read_triangle_mesh(os.path.join(original_input_dir, original_obj_files[i]))
            decoded_mesh = o3d.io.read_triangle_mesh(os.path.join(decoded_obj_path, decoded_obj_files[i]))
            d1_psnr = max(compute_D1_psnr(original_mesh, decoded_mesh), compute_D1_psnr(decoded_mesh, original_mesh))
            d1_psnr_values.append(d1_psnr)
            
        avg_psnr_5 = np.mean(d1_psnr_values[:5])
        avg_psnr_10 = np.mean(d1_psnr_values[:10])
        avg_psnr_15 = np.mean(d1_psnr_values[:15])
        avg_psnr = np.mean(d1_psnr_values)

        result_file.write(f"qp={qp}, Number of frames: {5}, Average D1 PSNR: {avg_psnr_5}\n")
        result_file.write(f"qp={qp}, Number of frames: {10}, Average D1 PSNR: {avg_psnr_10}\n")
        result_file.write(f"qp={qp}, Number of frames: {15}, Average D1 PSNR: {avg_psnr_15}\n")
        
        print(f"qp={qp}, Number of frames: {len(original_obj_files)}, Average D1 PSNR: {avg_psnr}\n")
# Out:
# qp=6, Number of frames: 15, Average D1 PSNR: 15.093491079065267
#
# qp=7, Number of frames: 15, Average D1 PSNR: 15.729469343442178
#
# qp=8, Number of frames: 15, Average D1 PSNR: 19.018651058972583
#
# qp=9, Number of frames: 15, Average D1 PSNR: 23.80865413983184
#
# qp=10, Number of frames: 15, Average D1 PSNR: 29.653292431060276
#
# qp=11, Number of frames: 15, Average D1 PSNR: 35.63227143484624
#
# qp=12, Number of frames: 15, Average D1 PSNR: 41.60794123090698
#
# qp=13, Number of frames: 15, Average D1 PSNR: 47.6325785142155
#
# qp=14, Number of frames: 15, Average D1 PSNR: 53.641483045088016

# %%
import matplotlib.pyplot as plt


Bitrates = [3.31, 3.99, 4.88, 6.13, 7.73, 9.44, 11.23, 12.81, 13.10]  
D1_PSNR = [12.50, 12.95, 15.83, 20.30, 26.48, 32.23, 38.03, 44.06, 50.07] 


ours_Bitrates = [2.71, 6, 9.65]  
ours_D1_PSNR = [28.55, 40, 50.75] 

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(Bitrates, D1_PSNR, marker='o', label='Draco')
plt.plot(ours_Bitrates, ours_D1_PSNR, marker='x', label='Ours')
plt.title('Bitrate - RD-performance - fps: 30')
plt.xlabel('Bitrate (Mbps)')
plt.ylabel('D1-PSNR')
plt.grid(True)
plt.legend()  # Show legend with labels
plt.xlim(0, 35)
plt.tight_layout()

# Display the plot
plt.show()
