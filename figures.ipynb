# %%
import open3d as o3d
import numpy as np
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import matplotlib.pyplot as plt


Bitrates = [3.31, 3.99, 4.88, 6.13, 7.73, 9.44, 11.23, 12.81, 13.10, 13.13, 13.23, 13.43, 13.89, 20.08, 25.61]  
D1_PSNR = [45.15, 50.41, 56.00, 61.76, 67.76, 73.80, 79.79, 85.81, 91.82, 97.87, 103.87, 109.87, 115.95, 121.45, 125.94] 


ours_Bitrates = [2.78, 4.34, 6.12, 7.92, 9.72, 11.51, 13.31, 15.11, 16.91]  
ours_D1_PSNR = [67.41, 73.41, 79.30, 84.82, 89.34, 91.97, 93.00, 93.31, 93.39] 

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(Bitrates, D1_PSNR, marker='o', label='Draco')
plt.plot(ours_Bitrates, ours_D1_PSNR, marker='x', label='Ours, GoF = 5')
plt.title('Bitrate - RD-performance - fps: 30')
plt.xlabel('Bitrate (Mbps)')
plt.ylabel('D1-PSNR')
plt.grid(True)
plt.legend()  # Show legend with labels
plt.xlim(0, 35)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt


Bitrates = [3.31, 3.99, 4.88, 6.13, 7.73, 9.44, 11.23, 12.81, 13.10, 13.13, 13.23, 13.43, 13.89, 20.08, 25.61]  
D2_PSNR = [48.23, 54.34, 60.37, 66.54, 72.52, 78.56, 84.58, 90.57, 96.58, 102.63, 108.64, 114.65, 120.71, 126.24, 130.77] 


ours_Bitrates = [1.79, 2.78, 4.34, 6.12, 7.92, 9.72, 11.51, 13.31, 15.11, 16.91]    
ours_D2_PSNR = [66.15, 72.18, 78.18, 84.10, 89.61, 94.17, 96.78, 97.80, 98.11, 98.19] 

KDDI_Bitrates = [2.18, 3.90, 9.12, 13.97, 21.25]    
KDDI_D2_PSNR = [70.79, 71.15, 77.26, 80.01, 80.75] 


# Plotting
plt.figure(figsize=(8, 6))
plt.plot(Bitrates, D2_PSNR, marker='o', label='Draco')
plt.plot(ours_Bitrates, ours_D2_PSNR, marker='x', label='Ours, GoF = 5')
plt.plot(KDDI_Bitrates, KDDI_D2_PSNR, marker='^', label='KDDI')
plt.title('Bitrate - RD-performance - fps: 30')
plt.xlabel('Bitrate (Mbps)')
plt.ylabel('D2-PSNR')
plt.grid(True)
plt.legend()  # Show legend with labels
plt.xlim(0, 35)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt


Bitrates = [3.31, 3.99, 4.88, 6.13, 7.73, 9.44, 11.23, 12.81, 13.10, 13.13, 13.23, 13.43, 13.89, 20.08]  
D2_PSNR = [48.23, 54.34, 60.37, 66.54, 72.52, 78.56, 84.58, 90.57, 96.58, 102.63, 108.64, 114.65, 120.71, 126.24] 


ours_Bitrates = [1.76, 3.03, 4.7, 6.12, 8.29, 10.10, 11.90, 13.69, 15.49, 17.29]    
ours_D2_PSNR = [68.52, 74.57, 80.51, 86.27, 91.42, 95.18, 97.15, 97.97, 98.19, 98.25] 

KDDI_Bitrates = [2.18, 3.90, 9.12, 13.97, 21.25]    
KDDI_D2_PSNR = [70.79, 71.15, 77.26, 80.01, 80.75] 

VDMC_Bitrates = [3.26, 5.50, 10.83, 15.32, 23.26]    
VDMC_D2_PSNR = [71.49, 71.91, 78.12, 80.55, 81.38] 


# Plotting
plt.figure(figsize=(12, 12))
plt.plot(ours_Bitrates, ours_D2_PSNR, marker='s', label='TVMC, GoF = 10', markersize=14, color = 'C1')
plt.plot(Bitrates, D2_PSNR, marker='o', label='Draco', markersize=14, color = 'C2')
plt.plot(KDDI_Bitrates, KDDI_D2_PSNR, marker='^', label='KDDI', markersize=14, color = 'C0')
plt.plot(VDMC_Bitrates, VDMC_D2_PSNR, marker='D', label='V-DMC 4.0', markersize=14, color = 'C3')
#plt.title('Dancer - fps: 30')
plt.xlabel('Bitrate (Mbps)', fontsize=40)
plt.ylabel('D2-PSNR (dB)', fontsize=40)
plt.grid(True)
plt.legend(fontsize=34, loc = 'lower right')  # Show legend with labels
plt.xlim(0, 25)
plt.ylim(45, 130)
plt.xticks(fontsize=34)
plt.yticks(fontsize=34)
plt.tight_layout()
plt.savefig(r"G:\PycharmProjects\Mesh_Editing\Results/comparison_methods_Dancer.png", dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

draco_Bitrates = [3.31, 3.99, 4.88, 6.13, 7.73, 9.44, 11.23, 12.81, 13.10, 13.13, 13.23, 13.43, 13.89, 20.08]    
draco_RMSE = [-1.92, -2.18, -2.46, -2.75, -3.05, -3.36, -3.66, -3.96, -4.26, -4.56, -4.86, -5.16, -5.46, -5.74] 

ours_Bitrates = [1.79, 2.78, 4.34, 6.12, 7.92, 9.72, 11.51, 13.31, 15.11, 16.91]    
ours_RMSE = [-2.74, -3.04, -3.34, -3.63, -3.91, -4.13, -4.27, -4.32, -4.33, -4.34] 



# Plotting
plt.figure(figsize=(8, 6))
plt.plot(draco_Bitrates, draco_RMSE, marker='o', label='Draco log of RMSE')
plt.plot(ours_Bitrates, ours_RMSE, marker='x', label='Ours log of RMSE, GoF = 5')

plt.title('Dancer - fps: 30')
plt.xlabel('Bitrate (Mbps)')
plt.ylabel('log of RMSE')
plt.grid(True)
plt.legend()  # Show legend with labels
plt.xlim(0, 21)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Bitrates = 6 Mbps
draco_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Dancer\Dancer_qp_9/dancer_fr0005_qp_9_decoded.obj')
our_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Ours\Dancer\GoF5/decoded_dancer_fr0005.obj')
draco_results.compute_vertex_normals()
our_results.compute_vertex_normals()
draco_results.paint_uniform_color([0.5, 0.5, 0.5])
our_results.paint_uniform_color([0.5, 0.5, 0.5])
draco_vertices = np.array(draco_results.vertices)
#draco_vertices +=(1,0,0)
draco_results.vertices = o3d.utility.Vector3dVector(draco_vertices)
o3d.visualization.draw_geometries([our_results])

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.32096099853515625, 1.3192800283432007, 0.35126799345016479 ],
			"boundingbox_min" : [ -0.50814902782440186, -0.48340100049972534, -0.48922199010848999 ],
			"field_of_view" : 60.0,
			"front" : [ -0.045392480701668812, 0.12557912345960234, -0.99104460366164493 ],
			"lookat" : [ -0.14283791009970695, 0.47219398000098123, -0.058408417392185191 ],
			"up" : [ -0.0092877827702863378, 0.99197126517840606, 0.12612194952332589 ],
			"zoom" : 0.47999999999999976
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.32096099853515625, 1.3192800283432007, 0.35126799345016479 ],
			"boundingbox_min" : [ -0.50814902782440186, -0.48340100049972534, -0.48922199010848999 ],
			"field_of_view" : 60.0,
			"front" : [ -0.04578662630881513, 0.014987039363652919, -0.99883881257306439 ],
			"lookat" : [ -0.15844942994683545, 1.0734638441413729, 0.013105359959702391 ],
			"up" : [ -0.0076478440406389132, 0.99985288970853803, 0.015352831107530744 ],
			"zoom" : 0.1799999999999996
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.32096099853515625, 1.3192800283432007, 0.35126799345016479 ],
			"boundingbox_min" : [ -0.50814902782440186, -0.48340100049972534, -0.48922199010848999 ],
			"field_of_view" : 60.0,
			"front" : [ -0.044472335411250626, 0.038920262263048774, -0.99825218485533251 ],
			"lookat" : [ -0.10938216912597806, 0.68110661255237759, -0.027984832871174037 ],
			"up" : [ -0.015072469137207681, 0.99910094239073355, 0.03962483549563639 ],
			"zoom" : 0.27999999999999958
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
self_contact = o3d.io.read_triangle_mesh(r'G:\VS2022Projects\tvm-editing-master\TVMEditor.Test\bin\Release\net5.0\output\Basketball\output/deformed_016.obj')
no_self_contact = o3d.io.read_triangle_mesh(r'G:\VS2022Projects\tvm-editing-master\TVMEditor.Test\bin\Release\net5.0\output\Basketball\output/deformed_020.obj')
self_contact.compute_vertex_normals()
no_self_contact.compute_vertex_normals()
self_contact.paint_uniform_color([0.5, 0.5, 0.5])
no_self_contact.paint_uniform_color([0.5, 0.5, 0.5])
o3d.visualization.draw_geometries([no_self_contact])

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 3.4131970405578613, 13.973526954650879, 2.0747067928314209 ],
			"boundingbox_min" : [ -4.0074806213378906, -4.8104839324951172, -4.444817066192627 ],
			"field_of_view" : 60.0,
			"front" : [ 0.19058414034984877, 0.12427716957407292, -0.97377249425611034 ],
			"lookat" : [ -0.29714179039001465, 4.5815215110778809, -1.185055136680603 ],
			"up" : [ -0.029446732988100435, 0.99223152125141101, 0.12086975697600399 ],
			"zoom" : 0.5199999999999998
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
# Bitrates = 6 Mbps
draco_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Basketball\Basketball_qp_9/basketball_player_fr0018_qp_9_decoded.obj')
our_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Ours\Basketball\GoF5/decoded_Basketball_fr0018.obj')
draco_results.compute_vertex_normals()
our_results.compute_vertex_normals()
draco_results.paint_uniform_color([0.5, 0.5, 0.5])
our_results.paint_uniform_color([0.5, 0.5, 0.5])
draco_vertices = np.array(draco_results.vertices)
#draco_vertices +=(1,0,0)
draco_results.vertices = o3d.utility.Vector3dVector(draco_vertices)
o3d.visualization.draw_geometries([our_results])

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 3.3117399215698242, 13.916299819946289, 2.0804998874664307 ],
			"boundingbox_min" : [ -3.792140007019043, -4.807610034942627, -4.0744500160217285 ],
			"field_of_view" : 60.0,
			"front" : [ -0.022555868118307721, 0.089554675268055564, -0.99572646492451067 ],
			"lookat" : [ -0.18449746736376785, 4.7266372214323882, -0.98274107118403609 ],
			"up" : [ 0.0059034306360941438, 0.99597442481520115, 0.089443248044524415 ],
			"zoom" : 0.49999999999999978
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 3.3117399215698242, 13.916299819946289, 2.0804998874664307 ],
			"boundingbox_min" : [ -3.792140007019043, -4.807610034942627, -4.0744500160217285 ],
			"field_of_view" : 60.0,
			"front" : [ -0.022555868118307721, 0.089554675268055564, -0.99572646492451067 ],
			"lookat" : [ 0.15650951992500026, 11.149860570603073, -0.41276729568587045 ],
			"up" : [ 0.0059034306360941438, 0.99597442481520115, 0.089443248044524415 ],
			"zoom" : 0.21999999999999958
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 3.3117399215698242, 13.916299819946289, 2.0804998874664307 ],
			"boundingbox_min" : [ -3.792140007019043, -4.807610034942627, -4.0744500160217285 ],
			"field_of_view" : 60.0,
			"front" : [ -0.10020406983465956, 0.11638049004393053, -0.98813699754927986 ],
			"lookat" : [ -0.36535217867821174, 7.0013994317515769, -0.77515315602730772 ],
			"up" : [ 0.0067353908164913094, 0.99319212957280767, 0.1162928556067834 ],
			"zoom" : 0.21999999999999958
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
# Bitrates = 5.20 Mbps Draco, 4.97 Mbps TVMC, qp = 9, 8
draco_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Mitch\Mitch_qp_9/mitch_fr0008_qp_9_decoded.obj')
our_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Ours\Mitch\GoF10/decoded_Mitch_fr0008.obj')
draco_results.compute_vertex_normals()
our_results.compute_vertex_normals()
draco_results.paint_uniform_color([0.5, 0.5, 0.5])
our_results.paint_uniform_color([0.5, 0.5, 0.5])
draco_vertices = np.array(draco_results.vertices)
#draco_vertices +=(1,0,0)
draco_results.vertices = o3d.utility.Vector3dVector(draco_vertices)
o3d.visualization.draw_geometries([our_results])

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.65369802713394165, 1.7932100296020508, 0.4177669882774353 ],
			"boundingbox_min" : [ -0.40430399775505066, 0.0089229997247457504, -0.45866400003433228 ],
			"field_of_view" : 60.0,
			"front" : [ -0.2353872002116002, 0.28280660227957771, 0.92984584296733019 ],
			"lookat" : [ 0.12561185078277209, 0.91629636978487716, -0.055279374833513327 ],
			"up" : [ 0.11500128275581686, 0.95811167294398825, -0.26229130205363083 ],
			"zoom" : 0.55999999999999983
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.65369802713394165, 1.7932100296020508, 0.4177669882774353 ],
			"boundingbox_min" : [ -0.40430399775505066, 0.0089229997247457504, -0.45866400003433228 ],
			"field_of_view" : 60.0,
			"front" : [ -0.2353872002116002, 0.28280660227957771, 0.92984584296733019 ],
			"lookat" : [ 0.2498065103928814, 1.4902392251933034, -0.19840094346810491 ],
			"up" : [ 0.11500128275581686, 0.95811167294398825, -0.26229130205363083 ],
			"zoom" : 0.23999999999999957
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.65369802713394165, 1.7932100296020508, 0.4177669882774353 ],
			"boundingbox_min" : [ -0.40430399775505066, 0.0089229997247457504, -0.45866400003433228 ],
			"field_of_view" : 60.0,
			"front" : [ -0.16992184106902883, 0.41473808545197349, 0.89393449894460586 ],
			"lookat" : [ -0.039026923341321067, 0.34558484982835219, 0.10904915375911416 ],
			"up" : [ 0.148066070656655, 0.90757344002501839, -0.39292097129251458 ],
			"zoom" : 0.23999999999999957
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
# Bitrates = 5.20 Mbps Draco, 5.09 Mbps TVMC, qp = 9, 9
draco_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Draco\Thomas\Thomas_qp_9/thomas_fr0009_qp_9_decoded.obj')
our_results = o3d.io.read_triangle_mesh('G:\PycharmProjects\Mesh_Editing\Results\decode_Ours\Thomas\GoF10/decoded_Thomas_fr0009.obj')
draco_results.compute_vertex_normals()
our_results.compute_vertex_normals()
draco_results.paint_uniform_color([0.5, 0.5, 0.5])
our_results.paint_uniform_color([0.5, 0.5, 0.5])
draco_vertices = np.array(draco_results.vertices)
#draco_vertices +=(1,0,0)
draco_results.vertices = o3d.utility.Vector3dVector(draco_vertices)
o3d.visualization.draw_geometries([draco_results])

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.29497000575065613, 1.8111400604248047, 0.30771699547767639 ],
			"boundingbox_min" : [ -0.2587679922580719, -0.0027079998981207609, -0.24247199296951294 ],
			"field_of_view" : 60.0,
			"front" : [ -0.0035148275921855245, 0.1474313564070126, 0.9890660448802121 ],
			"lookat" : [ 0.025311525375468175, 0.95003828458128758, -0.012071480958498292 ],
			"up" : [ -0.0028387858707170041, 0.98906669796139079, -0.14744154190231179 ],
			"zoom" : 0.5199999999999998
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.29497000575065613, 1.8111400604248047, 0.30771699547767639 ],
			"boundingbox_min" : [ -0.2587679922580719, -0.0027079998981207609, -0.24247199296951294 ],
			"field_of_view" : 60.0,
			"front" : [ -0.079292064093935466, 0.016877700382678277, 0.99670853904314272 ],
			"lookat" : [ -0.0007907821687678432, 1.6112423270620571, -0.099066244723778049 ],
			"up" : [ -0.043481027271033042, 0.99884650551146192, -0.020372989348567846 ],
			"zoom" : 0.11999999999999962
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.29497000575065613, 1.8111400604248047, 0.30771699547767639 ],
			"boundingbox_min" : [ -0.2587679922580719, -0.0027079998981207609, -0.24247199296951294 ],
			"field_of_view" : 60.0,
			"front" : [ 0.030993629212179297, 0.16944549853377402, 0.98505208896529872 ],
			"lookat" : [ 0.0038620502491557088, 0.2542594533571535, -0.068620285628799821 ],
			"up" : [ 0.0038246875340746953, 0.98549823235778811, -0.1696425824636659 ],
			"zoom" : 0.19999999999999993
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}

# %%
import matplotlib.pyplot as plt


ours_Bitrates_5 = [1.79, 2.78, 4.34, 6.12, 7.92, 9.72, 11.51, 13.31, 15.11, 16.91]    
ours_D2_PSNR_5 = [66.15, 72.18, 78.18, 84.10, 89.61, 94.17, 96.78, 97.80, 98.11, 98.19] 

ours_Bitrates_10 = [1.76, 3.03, 4.7, 6.49, 8.29, 10.10, 11.90, 13.69, 15.49, 17.29]    
ours_D2_PSNR_10 = [68.52, 74.57, 80.51, 86.27, 91.42, 95.18, 97.15, 97.97, 98.19, 98.25] 

ours_Bitrates_15 = [1.77, 3.17, 4.89, 6.69, 8.49, 10.28, 12.08, 13.88, 15.68, 17.48]    
ours_D2_PSNR_15 = [68.68, 74.73, 80.70, 86.44, 91.63, 95.37, 97.28, 97.98, 98.17, 98.22] 



# Plotting
plt.figure(figsize=(16, 12))
plt.plot(ours_Bitrates_5, ours_D2_PSNR_5, marker='^', label='GoF = 5', markersize=12)
plt.plot(ours_Bitrates_10, ours_D2_PSNR_10, marker='o', label='GoF = 10', markersize=12)
plt.plot(ours_Bitrates_15, ours_D2_PSNR_15, marker='s', label='GoF = 15', markersize=12)
#plt.title('Dancer - fps: 30')
plt.xlabel('Bitrate (Mbps)', fontsize=30)
plt.ylabel('D2-PSNR (dB)', fontsize=30)
plt.grid(True)
plt.legend(fontsize=28, loc = 'lower right')  # Show legend with labels
plt.xlim(0, 20)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.tight_layout()
plt.savefig(r"G:\PycharmProjects\Mesh_Editing\Results/comparison_gof_Dancer.png", dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt


Bitrates = [4.02, 4.93, 6.19, 7.78, 9.50, 11.29, 12.89, 13.32, 13.38, 13.41, 13.63, 14.08, 23.91]  
D2_PSNR = [53.84, 59.83, 66.01, 71.99, 78.01, 84.03, 90.04, 96.06, 102.06, 109.43, 114.16, 120.17, 126.14] 


ours_Bitrates = [2.8, 4.41, 6.21, 8.01, 9.81, 11.61, 13.41, 15.21, 17.01, 18.8]    
ours_D2_PSNR = [72.23, 78.26, 84.13, 89.62, 93.97, 96.42, 97.34, 97.59, 97.66, 97.68] 

KDDI_Bitrates = [1.67, 3.05, 7.63, 12.21, 19.76]    
KDDI_D2_PSNR = [70.45, 71.61, 77.17, 80.04, 80.40] 

VDMC_Bitrates = [3.28, 5.42, 10.74, 15.52, 23.21]    
VDMC_D2_PSNR = [71.30, 72.60, 78.11, 80.92, 81.36] 


# Plotting
plt.figure(figsize=(12, 12))
plt.plot(ours_Bitrates, ours_D2_PSNR, marker='s', label='TVMC, GoF = 10', markersize=14, color = 'C1')
plt.plot(Bitrates, D2_PSNR, marker='o', label='Draco', markersize=14, color = 'C2')
plt.plot(KDDI_Bitrates, KDDI_D2_PSNR, marker='^', label='KDDI', markersize=14, color = 'C0')
plt.plot(VDMC_Bitrates, VDMC_D2_PSNR, marker='D', label='V-DMC 4.0', markersize=14, color = 'C3')
#plt.title('Basketball - fps: 30')
plt.xlabel('Bitrate (Mbps)', fontsize=40)
plt.ylabel('D2-PSNR (dB)', fontsize=40)
plt.grid(True)
plt.legend(fontsize=34, loc = 'lower right')  # Show legend with labels
plt.xlim(0, 25)
plt.ylim(45, 130)
plt.xticks(fontsize=34)
plt.yticks(fontsize=34)
plt.tight_layout()
plt.savefig(r"G:\PycharmProjects\Mesh_Editing\Results/comparison_methods_Basketball.png", dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt


Bitrates = [3.32, 4.11, 5.20, 6.47, 7.81, 9.19, 10.50, 10.95, 11.01, 11.45, 12.20, 18.77, 20.11]  
D2_PSNR = [54.85, 60.94, 66.99, 73.02, 79.03, 85.05, 91.08, 97.14, 103.11, 109.13, 115.14, 121.18, 126.84] 


ours_Bitrates = [3.19, 4.97, 6.77, 8.57, 10.37, 12.17, 13.98, 15.78, 17.58, 19.38]    
ours_D2_PSNR = [81.67, 87.46, 92.63, 96.34, 98.15, 98.76, 98.93, 98.97, 98.98, 98.98] 

KDDI_Bitrates = [2.61, 3.28, 5.05, 7.72, 12.77]    
KDDI_D2_PSNR = [73.50, 74.62, 77.41, 81.04, 83.22] 

VDMC_Bitrates = [3.43, 4.37, 6.54, 8.68, 12.88]    
VDMC_D2_PSNR = [73.57, 74.79, 77.66, 81.10, 83.29] 


# Plotting
plt.figure(figsize=(12, 12))
plt.plot(ours_Bitrates, ours_D2_PSNR, marker='s', label='TVMC, GoF = 10', markersize=14, color = 'C1')
plt.plot(Bitrates, D2_PSNR, marker='o', label='Draco', markersize=14, color = 'C2')
plt.plot(KDDI_Bitrates, KDDI_D2_PSNR, marker='^', label='KDDI', markersize=14, color = 'C0')
plt.plot(VDMC_Bitrates, VDMC_D2_PSNR, marker='D', label='V-DMC 4.0', markersize=14, color = 'C3')
#plt.title('Mitch - fps: 30')
plt.xlabel('Bitrate (Mbps)', fontsize=40)
plt.ylabel('D2-PSNR (dB)', fontsize=40)
plt.grid(True)
plt.legend(fontsize=34, loc = 'lower right')  # Show legend with labels
plt.xlim(0, 25)
plt.ylim(45, 130)
plt.xticks(fontsize=34)
plt.yticks(fontsize=34)
plt.tight_layout()
plt.savefig(r"G:\PycharmProjects\Mesh_Editing\Results/comparison_methods_Mitch.png", dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt


Bitrates = [3.34, 4.13, 5.20, 6.46, 7.81, 9.18, 10.32, 10.90, 11.01, 11.09, 11.30, 11.84, 18.83]  
D2_PSNR = [53.53, 59.59, 65.65, 71.72, 77.79, 83.95, 89.76, 95.79, 101.78, 107.81, 113.81, 119.83, 125.50] 


ours_Bitrates = [1.94, 3.34, 5.09, 6.89, 8.69, 10.49, 12.29, 14.09, 15.89, 17.69]    
ours_D2_PSNR = [69.52, 75.53, 81.50, 87.18, 92.14, 95.44, 96.91, 97.37, 97.49, 97.52] 

KDDI_Bitrates = [1.64, 2.82, 4.97, 7.06, 11.98]    
KDDI_D2_PSNR = [74.04, 77.16, 79.96, 81.36, 83.52] 

VDMC_Bitrates = [3.25, 4.33, 6.58, 8.82, 13.79]    
VDMC_D2_PSNR = [74.30, 77.45, 80.21, 81.62, 83.74] 


# Plotting
plt.figure(figsize=(12, 12))
plt.plot(ours_Bitrates, ours_D2_PSNR, marker='s', label='TVMC, GoF = 10', markersize=14, color = 'C1')
plt.plot(Bitrates, D2_PSNR, marker='o', label='Draco', markersize=14, color = 'C2')
plt.plot(KDDI_Bitrates, KDDI_D2_PSNR, marker='^', label='KDDI', markersize=14, color = 'C0')
plt.plot(VDMC_Bitrates, VDMC_D2_PSNR, marker='D', label='V-DMC 4.0', markersize=14, color = 'C3')
#plt.title('Thomas - fps: 30')
plt.xlabel('Bitrate (Mbps)', fontsize=40)
plt.ylabel('D2-PSNR (dB)', fontsize=40)
plt.grid(True)
plt.legend(fontsize=34, loc = 'lower right')  # Show legend with labels
plt.xlim(0, 25)
plt.ylim(45, 130)
plt.xticks(fontsize=34)
plt.yticks(fontsize=34)
plt.tight_layout()
plt.savefig(r"G:\PycharmProjects\Mesh_Editing\Results/comparison_methods_Thomas.png", dpi=300, bbox_inches='tight')
# Display the plot
plt.show()
