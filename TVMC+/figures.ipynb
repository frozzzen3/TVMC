# %%
import matplotlib.pyplot as plt


Bitrates = [15.17, 18.02, 22.20, 28.24, 35.24, 42.64, 50.05, 57.62, 65.19, 72.95, 81.03, 89.59, 97.10, 104.61]  
D2_PSNR = [49.27, 55.23, 61.29, 67.29, 73.34, 79.39, 85.39, 91.42, 97.43, 103.42, 109.43, 115.34, 120.92, 125.55] 


ours_Bitrates = [11.50, 13.40, 15.16, 27.39]    
ours_D2_PSNR = [59.27, 59.32, 61.15, 61.15] 




# Plotting
plt.figure(figsize=(12, 12))
plt.plot(ours_Bitrates, ours_D2_PSNR, marker='s', label='TVMC', markersize=14, color = 'C1')
plt.plot(Bitrates, D2_PSNR, marker='o', label='Draco', markersize=14, color = 'C2')

#plt.title('Dancer - fps: 30')
plt.xlabel('Bitrate (Mbps)', fontsize=40)
plt.ylabel('D1-PSNR (dB)', fontsize=40)
plt.grid(True)
plt.legend(fontsize=34, loc = 'lower right')  # Show legend with labels
plt.xlim(10, 60)
plt.ylim(45, 100)
plt.xticks(fontsize=34)
plt.yticks(fontsize=34)
plt.tight_layout()
plt.savefig(r"G:\PycharmProjects\Mesh_Editing\Results/comparison_methods_Dancer.png", dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
onlycoarse = o3d.io.read_triangle_mesh(r"G:\VS2022Projects\tvm-editing\TVMEditor.Test\bin\Release\net5.0\output\drinking\reference\onlycoarse/fitting_mesh_dancer_004.obj")
onlycoarse.compute_vertex_normals()
o3d.visualization.draw_geometries([onlycoarse])

# %%
{
	"class_name" : "ViewTrajectory",
	"interval" : 29,
	"is_loop" : false,
	"trajectory" : 
	[
		{
			"boundingbox_max" : [ 0.98237502574920654, 3.8298499584197998, 2.6029999256134033 ],
			"boundingbox_min" : [ -0.81469202041625977, -4.5310301780700684, -1.2625299692153931 ],
			"field_of_view" : 60.0,
			"front" : [ 0.17669946456628677, -0.71591605230668787, -0.67545651619596914 ],
			"lookat" : [ 0.26340266510124749, -0.2657019039908699, 0.65345410302853002 ],
			"up" : [ 0.98288831626145401, 0.1646261751169831, 0.082636433992982358 ],
			"zoom" : 0.15999999999999961
		}
	],
	"version_major" : 1,
	"version_minor" : 0
}
